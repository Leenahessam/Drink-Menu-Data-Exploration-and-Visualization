# %%
#imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Read csv file

# %%
df = pd.read_csv("drinkMenu.csv")
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %% [markdown]
# Data Preparation and Cleaning

# %%
#remove spaces to easily retrieve columns
df.columns = df.columns.str.replace(' ','')
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Beverage_category      242 non-null    object
#  1   Beverage               242 non-null    object
#  2   Beverage_prep          242 non-null    object
#  3   Calories               242 non-null    int64
#  4   TotalFat(g)            242 non-null    object
#  5   TransFat(g)            242 non-null    float64
#  6   SaturatedFat(g)        242 non-null    float64
#  7   Sodium(mg)             242 non-null    int64
#  8   TotalCarbohydrates(g)  242 non-null    int64
#  9   Cholesterol(mg)        242 non-null    int64
#  10  DietaryFibre(g)        242 non-null    int64
#  11  Sugars(g)              242 non-null    int64
#  12  Protein(g)             242 non-null    float64
#  13  VitaminA(%DV)          242 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# Beverage_category        0
# Beverage                 0
# Beverage_prep            0
# Calories                 0
# TotalFat(g)              0
# TransFat(g)              0
# SaturatedFat(g)          0
# Sodium(mg)               0
# TotalCarbohydrates(g)    0
# Cholesterol(mg)          0
# DietaryFibre(g)          0
# Sugars(g)                0
# Protein(g)               0
# VitaminA(%DV)            0
# VitaminC(%DV)            0
# Calcium(%DV)             0
# Iron(%DV)                0
# Caffeine(mg)             1
# dtype: int64

# %% [markdown]
# Only Caffeine has one null value, we can fill it with mode

# %%
df['Caffeine(mg)'].fillna(df['Caffeine(mg)'].mode()[0], inplace=True)

# %%
#now make sure everything is okay
df.isna().sum()
# Out:
# Beverage_category        0
# Beverage                 0
# Beverage_prep            0
# Calories                 0
# TotalFat(g)              0
# TransFat(g)              0
# SaturatedFat(g)          0
# Sodium(mg)               0
# TotalCarbohydrates(g)    0
# Cholesterol(mg)          0
# DietaryFibre(g)          0
# Sugars(g)                0
# Protein(g)               0
# VitaminA(%DV)            0
# VitaminC(%DV)            0
# Calcium(%DV)             0
# Iron(%DV)                0
# Caffeine(mg)             0
# dtype: int64

# %%
#check for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no duplicates in data

# %%
#checking data correlation to make sure that there is no unnecessary data/columns
corr_matrix = df.corr()

plt.figure(figsize=(15,15))
plt.title('Correlation Heatmap of drinkMenu Dataset')
a = sns.heatmap(corr_matrix, square=True, annot=True, fmt='.2f', linecolor='black')
a.set_xticklabels(a.get_xticklabels(), rotation=30)
a.set_yticklabels(a.get_yticklabels(), rotation=30)
plt.show()

# %% [markdown]
# Assuming our threshold is 90% correlation then:
# sodium and saturated fats, sugars, cholestrol and colories are strongly correlated, we can keep either one

# %%
corr_features = []
for i in range(len(corr_matrix .columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > 0.9:
            colname = corr_matrix.columns[i]
            if colname not in corr_features:
                corr_features.append(colname)

corr_features
# Out:
# ['Sodium(mg)', 'Cholesterol(mg)', 'Sugars(g)']

# %%
df_cleaned = df.drop(labels=corr_features, axis=1)

# %%
df_cleaned.head()
# Out:
#          Beverage_category       Beverage      Beverage_prep  Calories  \
# 0                   Coffee  Brewed Coffee              Short         3
# 1                   Coffee  Brewed Coffee               Tall         4
# 2                   Coffee  Brewed Coffee             Grande         5
# 3                   Coffee  Brewed Coffee              Venti         5
# 4  Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70
#
#   TotalFat(g)  TransFat(g)  SaturatedFat(g)  TotalCarbohydrates(g)  \
# 0         0.1          0.0              0.0                      5
# 1         0.1          0.0              0.0                     10
# 2         0.1          0.0              0.0                     10
# 3         0.1          0.0              0.0                     10
# 4         0.1          0.1              0.0                     75
#
#    DietaryFibre(g)  Protein(g) VitaminA(%DV) VitaminC(%DV) Calcium(%DV)  \
# ...

# %% [markdown]
# **Data Visualization**

# %% [markdown]
# Which drink has the highest calories from the dataset?

# %%
sns.set(rc = {'figure.figsize':(15,8)})
fig = sns.scatterplot(data=df.sort_values(by=['Calories']), x="Beverage", y="Calories")
plt.setp(fig.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# White Chocolate Mocha (Without Whipped Cream) has highest calories

# %%
#double check answer
answer = df[df['Calories'] == df['Calories'].max()]
answer
# Out:
#             Beverage_category                                       Beverage  \
# 84  Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
#
#    Beverage_prep  Calories TotalFat(g)  TransFat(g)  SaturatedFat(g)  \
# 84       2% Milk       510          15          9.0              0.2
#
#     Sodium(mg)  TotalCarbohydrates(g)  Cholesterol(mg)  DietaryFibre(g)  \
# 84          35                    330               77                0
#
#     Sugars(g)  Protein(g) VitaminA(%DV) VitaminC(%DV) Calcium(%DV) Iron(%DV)  \
# 84         74        19.0           20%            4%          60%        2%
#
#    Caffeine(mg)
# 84          150

# %% [markdown]
# Highest Sugar Drink ?

# %%
sns.set(rc = {'figure.figsize':(15,8)})
fig = sns.scatterplot(data=df.sort_values(by=['Sugars(g)']), x="Beverage", y="Sugars(g)")
plt.setp(fig.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# Java Chip (Without Whipped Cream) has the highest sugar

# %%
#double check answer
answer = df[df['Sugars(g)'] == df['Sugars(g)'].max()]
answer
# Out:
#                Beverage_category                           Beverage  \
# 214  Frappuccino® Blended Coffee  Java Chip (Without Whipped Cream)
# 215  Frappuccino® Blended Coffee  Java Chip (Without Whipped Cream)
#
#          Beverage_prep  Calories TotalFat(g)  TransFat(g)  SaturatedFat(g)  \
# 214  Venti Nonfat Milk       420           5          4.0              0.0
# 215         Whole Milk       460          10          7.0              0.2
#
#      Sodium(mg)  TotalCarbohydrates(g)  Cholesterol(mg)  DietaryFibre(g)  \
# 214           5                    340               90                2
# 215          15                    340               90                2
#
#      Sugars(g)  Protein(g) VitaminA(%DV) VitaminC(%DV) Calcium(%DV) Iron(%DV)  \
# 214         84         7.0           10%            0%          20%       35%
# 215         84         7.0            6%            0%          15%       35%
#
#     Caffeine(mg)
# 214          145
# 215          145

# %% [markdown]
# Thank you 😀
